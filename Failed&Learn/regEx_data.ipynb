# %%
import numpy as np
import pandas as pd
import re

pd.options.display.max_colwidth = 300

# %%
data=pd.read_excel("list_of_product.xlsx")

# %%
data.head(10)
# Out:
#                                                                                                                                                                                            product
# 0                             (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿129 - ฿149ขายแล้ว 42.9พัน ชิ้นจังหวัดกรุงเทพมหานคร
# 1                                                                                                       กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿350 - ฿390ขายแล้ว 23พัน ชิ้นจังหวัดพิจิตร
# 2                       ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿125 - ฿185ขายแล้ว 52พัน ชิ้นจังหวัดนนทบุรี
# 3  [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿119 - ฿125ขายแล้ว 179.4พัน ชิ้นจังหวัดสมุทรปราการ
# ...

# %%
# """
# Regular Expression
# - Describe the product 
# - split the product detail, price, amount of sold out, province
# """
# describe_product=re.

# %%
# The Python "TypeError: expected string or bytes-like object" occurs 
# when we pass an argument of a different type to a method 
# that expects a string argument, e.g. re.sub(). 
# To solve the error, make sure to pass a string argument to the method.

# put str() to the argument to make sure that the arg are string

describe_product=re.findall(r".*\w\S*฿",str(data))
print(describe_product)
# Out:
# ['0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿', '1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿', '2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿', '3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿', '4                                                                                 TS MEN เสื้อยืดคอกลมแขนสั้น เสื้อยืดผู้ชาย(มี3สี)รุ่น 0091ส่วนลด 5%฿159฿', '5                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿', '6                                          ชุดกีฬาลำลอง, ฤดูใบไม้ผลิแล
# ...

# %%
data
# Out:
#                                                                                                                                                                                              product
# 0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿129 - ฿149ขายแล้ว 42.9พัน ชิ้นจังหวัดกรุงเทพมหานคร
# 1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿350 - ฿390ขายแล้ว 23พัน ชิ้นจังหวัดพิจิตร
# 2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿125 - ฿185ขายแล้ว 52พัน ชิ้นจังหวัดนนทบุรี
# 3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿119 - ฿125ขายแล้ว 179.4พัน ชิ้นจังหวัดสมุทรปราการ
# ...

# %%
for price in re.findall(r".*",str(data)):
    print(re.findall(".*\w\฿",price))
# Out:
# []
# []
# ['0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿']
# []
# []
# []
# []
# []
# []
# []
# ['4                                                                                 TS MEN เสื้อยืดคอกลมแขนสั้น เสื้อยืดผู้ชาย(มี3สี)รุ่น 0091ส่วนลด 5%฿159฿']
# []
# ['5                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿']
# []
# []
# []
# ['7                                  🔥พร้อมส่ง🔥 เสื้อยืด เสื้อยืดสีพื้น เสื้อยืดคอกลม เสื้อผู้ชาย รุ่น ST01 ไซส์ M L XL XXL 3XLส่วนลด 5%ช้อปเพิ่มคุ้มกว่า฿49฿']
# []
# ['8                                                                                                           เสื้อยืดชาย oversize คอกลม แขนสั้นส่วนลด 50%฿79฿']
# []
# ...

# %%
# (.*฿) -> return ฿ ตัดสุดท้าย
# (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿

price_list=[]
for price in re.findall(r".*",str(data)):
    price_list.append(re.findall(".*\S\฿",price))
price_list
# Out:
# [[],
#  [],
#  ['0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿'],
#  [],
#  ['1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿'],
#  [],
#  ['2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿'],
#  [],
#  ['3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿'],
#  [],
#  ['4                                                                                 TS MEN เสื้อยืดคอกลมแขนสั้น เสื้อยืดผู้ชาย(มี3สี)รุ่น 0091ส่วนลด 5%฿159฿'],
#  [],
# ...

# %%
price_list[10]
# Out:
# ['4                                                                                 TS MEN เสื้อยืดคอกลมแขนสั้น เสื้อยืดผู้ชาย(มี3สี)รุ่น 0091ส่วนลด 5%฿159฿']

# %%
len(price_list)
# Out:
# 122

# %%
price_list[0]
# Out:
# []

# %%
removed_null=[]
raw_list=re.findall(r".*",str(data))
for prices in raw_list:
    # check condition if the element is null
    if prices!= None:
        removed_null.append(re.findall(".*\S\฿",prices))
    else:
        pass
removed_null
# Out:
# [[],
#  [],
#  ['0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿'],
#  [],
#  ['1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿'],
#  [],
#  ['2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿'],
#  [],
#  ['3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿'],
#  [],
#  ['4                                                                                 TS MEN เสื้อยืดคอกลมแขนสั้น เสื้อยืดผู้ชาย(มี3สี)รุ่น 0091ส่วนลด 5%฿159฿'],
#  [],
# ...

# %%
len(removed_null)
# Out:
# 122

# %%
removed_null[36]
# Out:
# ['17         เสื้อเชิ้ตแขนสั้นผู้ชาย TOBY SHORT SLEEVE - RALPH T OFFICIAL เสื้อเชิ้ตผู้ชาย เสื้อเชิ้ตผู้ชายแขนสั้น เสื้อเชิ้ตคอจีนช้อปเพิ่มคุ้มกว่า฿']

# %%
removed_null
# Out:
# [[],
#  [],
#  ['0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿'],
#  [],
#  ['1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿'],
#  [],
#  ['2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿'],
#  [],
#  ['3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿'],
#  [],
#  ['4                                                                                 TS MEN เสื้อยืดคอกลมแขนสั้น เสื้อยืดผู้ชาย(มี3สี)รุ่น 0091ส่วนลด 5%฿159฿'],
#  [],
# ...

# %%
test=pd.DataFrame(removed_null,columns=['product'])

# %%
test.head(10)
# Out:
#                                                                                                                                                        product
# 0                                                                                                                                                         None
# 1                                                                                                                                                         None
# 2           0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿
# 3                                                                                                                                                         None
# 4  1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿
# ...

# %%
test[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
len(test)
# Out:
# 122

# %%
test.dropna(inplace=True)

# %%
len(test)
# Out:
# 60

# %%
test
# Out:
#                                                                                                                                                                                       product
# 2                                          0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿
# 4                                 1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿
# 6                                  2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿
# 8                                         3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿
# ...

# %%
test.to_excel("removed_null.xlsx",encoding='utf-8',index=False)

# %%
removed_list=pd.read_excel('removed_null.xlsx')

# %%
removed_list
# Out:
#                                                                                                                                                                                      product
# 0                                         0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿
# 1                                1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿
# 2                                 2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿
# 3                                        3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿
# ...

# %%
removed_list.head(2) #multiple access
# Out:
#                                                                                                                                                        product
# 0           0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿
# 1  1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿

# %%
# removing the number in front of the sentense
find_number=re.findall(r'.*',str(removed_list))
removed_num_list=[]
for del_no in find_number:
    if del_no!=None:
        # remove from sentence
        removing_num=re.sub(r'.*^(\A[0-9][0-9][0-9])|(\A[0-9][0-9])|(\A[0-9])','',str(find_number))
        # append to new list
        removed_num_list.append(removing_num)
removed_num_list
# Out:
# ["['                                                                                                                                                                                     product', '', '0                                         0                               (ลูกค้าใหม่ 1 บาท) เสื้อ+กางเกงขาสั้น ผ้าเบา ไม่หด ไม่ย้วย เสื้อยืดคอกลมสีพื้น ชุดกีฬาผู้ชาย ชุดซื้อ 2 ชิ้น ลด ฿5฿', '', '1                                1                                                                                                         กางเกงวินเทจ 6 กระเป๋า MAFEAR (มีหลายสีให้เลือก)฿', '', '2                                 2                         ใส่โค้ด 615FASH150 ลด150 เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น ผ้านิ่มนุ่ม เบา ใส่สบาย ไม่ต้องรีด ระบายความร้อนได้ยอดเยี่ยมส่วนลด 50%฿', '', '3                                        3    [ลด 15% โค้ด SPPDAYH15] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXLชาย/หญิงส่วนลด 20%ซื้อ 3 ชิ้น ลด 5%฿', '', '4             
# ...

# %%
# removing the number in front of the sentense
find_number=re.findall(r'.*',str(removed_list))
removed_num_list=[]
for del_no in find_number:
    if del_no!=None:
        # remove from sentence
        removed_list_=re.sub(r'.*^(\A[0-9][0-9][0-9])|(\A[0-9][0-9])|(\A[0-9])','',str(del_no))
        # append to new list
        removed_num_list.append(removed_list_)
removed_num_list
# Out:
# ['                                                                                                                                                                                     product',
#  '']
